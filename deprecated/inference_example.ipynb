# %%
import torch
from torchvision.models import wide_resnet50_2, resnet18
import cv2
import matplotlib.pyplot as plt

from padim_utils import AnomalyDetector

# %% [markdown]
# ## Init Anomaly Detector

# %%
anomaly_detector = AnomalyDetector('/home/plejd/Projects/vision/tool_testing/PaDiM_test/PaDiM-Anomaly-Detection-Localization-master/batch_2_up.pkl')
# Out:
# /home/plejd/anaconda3/envs/vision/lib/python3.7/site-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 804: forward compatibility was attempted on non supported HW (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0

# %% [markdown]
# ## Load images

# %%
paths = [
    '../tool_testing/PaDiM_test/aligned_pucks/defect_up/1622451238634_right_0_up.png', 
    '../tool_testing/PaDiM_test/aligned_pucks/defect_up/1622451238634_right_1_up.png', 
    '../tool_testing/PaDiM_test/aligned_pucks/defect_up/1622451238634_right_2_up.png', 
    '../tool_testing/PaDiM_test/aligned_pucks/defect_up/1622451238634_right_3_up.png', 
    '../tool_testing/PaDiM_test/aligned_pucks/defect_up/1622451238634_right_4_up.png', 
]
images = []
for path in paths:
    im = cv2.imread(path)
    im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
    images.append(im)
#     plt.imshow(im)
#     plt.show()

# %%
img_scores, image = anomaly_detector(images, 7)
# Out:
# --------------
# [ 5.082516   5.32097   12.047317   5.0733433 15.814321 ]
# [1.0, 1.0, 0.0, 1.0, 0.0]

# %%
print(img_scores)
plt.imshow(image)
plt.show()
# Out:
# [1, 1, 0, 1, 0]
